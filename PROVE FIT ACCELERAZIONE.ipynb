# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from scipy import stats

import pandas as pd
import random
import math

# libreria locale
import my_lib_modificata as my

# %%
# PARAMETRI DELLA RETTA DI CALIBRAZIONE
m =  173.7133
sigma_m =  0.1915
c =  -0.0152
sigma_c = 0.0011
cov = -0.0002
rho = -0.9585

# %%
# ANGOLO 1
df = pd.read_csv('tang1_1.txt', header=1, sep='\t')
df = df.rename(columns={"Tempo ( s )":"t", "Tempo trascorso ( s )":"DeltaT"})
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")
# Out:
# <AxesSubplot: xlabel='t'>

# %%
# TAGLIO I TEMPI INUTILI
df = df.drop(df[df.t <6 ].index | df[df.t > 9].index)
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")
# Out:
# /var/folders/sh/g1b60r3n5jxcwjkdwqkp_3xw0000gn/T/ipykernel_2717/2262265016.py:2: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   df = df.drop(df[df.t <6 ].index | df[df.t > 9].index)
# <AxesSubplot: xlabel='t'>

# %%
# USO RETTA CALIBRAZIONE
dTi = df.DeltaT.to_numpy()
xi = m*dTi + c

# %%
# CALCOLO V
t = df.t.to_numpy()

v = np.zeros(shape=len(xi)-1)
for i in range (0, len(xi)-1):
    v[i]=(xi[i+1]-xi[i])/(t[i+1]-t[i])

t = np.delete(t,len(t)-1)

plt.plot(t, v, '.')
plt.title("V angolo 1")
# Out:
# Text(0.5, 1.0, 'V angolo 1')

# %%
# ANGOLO 2
df = pd.read_csv('tang2_1.txt', header=1, sep='\t')
df = df.rename(columns={"Tempo ( s )":"t", "Tempo trascorso ( s )":"DeltaT"})
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")
# Out:
# <AxesSubplot: xlabel='t'>

# %%
# TAGLIO I TEMPI INUTILI
df = df.drop(df[df.t <4.3 ].index | df[df.t > 6.5].index)
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")
# Out:
# /var/folders/sh/g1b60r3n5jxcwjkdwqkp_3xw0000gn/T/ipykernel_2717/2646084891.py:2: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   df = df.drop(df[df.t <4.3 ].index | df[df.t > 6.5].index)
# <AxesSubplot: xlabel='t'>

# %%
# USO RETTA CALIBRAZIONE
dTi = df.DeltaT.to_numpy()
xi = m*dTi + c

# %%
# CALCOLO V
t = df.t.to_numpy()

v = np.zeros(shape=len(xi)-1)
for i in range (0, len(xi)-1):
    v[i]=(xi[i+1]-xi[i])/(t[i+1]-t[i])

t = np.delete(t,len(t)-1)

plt.plot(t, v, '.')
plt.title("V angolo 2")
# Out:
# Text(0.5, 1.0, 'V angolo 2')

# %%
# ANGOLO 3
df = pd.read_csv('tang3_1.txt', header=1, sep='\t')
df = df.rename(columns={"Tempo ( s )":"t", "Tempo trascorso ( s )":"DeltaT"})
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")
# Out:
# <AxesSubplot: xlabel='t'>

# %%
# TAGLIO I TEMPI INUTILI
df = df.drop(df[df.t <3.5 ].index | df[df.t > 5.5].index)
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")
# Out:
# /var/folders/sh/g1b60r3n5jxcwjkdwqkp_3xw0000gn/T/ipykernel_2717/765998947.py:2: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   df = df.drop(df[df.t <3.5 ].index | df[df.t > 5.5].index)
# <AxesSubplot: xlabel='t'>

# %%
# USO RETTA CALIBRAZIONE
dTi = df.DeltaT.to_numpy()
xi = m*dTi + c

# %%
# CALCOLO V
t = df.t.to_numpy()

v = np.zeros(shape=len(xi)-1)
for i in range (0, len(xi)-1):
    v[i]=(xi[i+1]-xi[i])/(t[i+1]-t[i])

n = [0, 5, 8, 10, 14, 21, 22, 31, 34]
t = np.delete(t, n)
t = np.delete(t, len(t)-1)

plt.plot(t, v, '.')
plt.title("V angolo 3")
# Out:
# Text(0.5, 1.0, 'V angolo 3')

# %%
# ANGOLO 4
df = pd.read_csv('tang4_1.txt', header=1, sep='\t')
df = df.rename(columns={"Tempo ( s )":"t", "Tempo trascorso ( s )":"DeltaT"})
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")

# %%
# TAGLIO I TEMPI INUTILI
df = df.drop(df[df.t <5.2 ].index | df[df.t > 7].index)
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")

# %%
# USO RETTA CALIBRAZIONE
dTi = df.DeltaT.to_numpy()
xi = m*dTi + c

# %%
# CALCOLO V
t = df.t.to_numpy()

v = np.zeros(shape=len(xi)-1)
for i in range (0, len(xi)-1):
    v[i]=(xi[i+1]-xi[i])/(t[i+1]-t[i])

t = np.delete(t,len(t)-1)

plt.plot(t, v, '.')
plt.title("V angolo 4")

# %%
# ANGOLO 5
df = pd.read_csv('tang5_1.txt', header=1, sep='\t')
df = df.rename(columns={"Tempo ( s )":"t", "Tempo trascorso ( s )":"DeltaT"})
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")

# %%
# TAGLIO I TEMPI INUTILI
df = df.drop(df[df.t <3.2 ].index | df[df.t > 4.7].index)
df.plot(x="t", y="DeltaT", linestyle="None", marker=".")

# %%
# USO RETTA CALIBRAZIONE
dTi = df.DeltaT.to_numpy()
xi = m*dTi + c

# %%
# CALCOLO V
t = df.t.to_numpy()

v = np.zeros(shape=len(xi)-1)
for i in range (0, len(xi)-1):
    v[i]=(xi[i+1]-xi[i])/(t[i+1]-t[i])

t = np.delete(t,len(t)-1)

plt.plot(t, v, '.')
plt.title("V angolo 5")
